# %% [markdown]
# <a href="https://colab.research.google.com/github/tuonglong1012/Khai_Pha_Cuoi_Ky/blob/main/Khai_Pha_CK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code here

# %%
print("hehehe")
# Out:
# hehehe
